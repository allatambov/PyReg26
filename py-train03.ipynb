# %% [markdown]
# ## Введение в регрессионный анализ
#
# ### Задачи для тренировки по итогам недели №3

# %% [markdown]
# ### Часть 1
#
# В файле `games_w.csv` сохранены результаты Зимних Олимпийских игр в разные годы. Одна строка таблицы соответствует одной команде – одной стране – в определенный год.
#
# Показатели в файле:
#
# * `year`: год;
# * `host_country`: страна, принимающая Игры;
# * `host_city`: город, где проходили Игры;
# * `country`: команда, страна-участник Игр;
# * `gold`: количество золотых медалей, полученных командой страны на Играх;
# * `silver`: количество серебряных медалей, полученных командой страны на Играх;
# * `bronze`: количество бронзовых медалей, полученных командой страны на Играх.
#
# Загрузите данные из файла `games_w.csv` (скачать [здесь](https://github.com/allatambov/PyReg26/blob/main/games_w.csv)) и сохраните в датафрейм.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 1
#
# Выведите информацию о типах столбцов в датафрейме. Сколько столбцов типа `int`?

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 2
#
# Выведите описательные статистики по всем числовым столбцам датафрейма. Укажите нижний квартиль показателя «количество золотых медалей».

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 3
#
# Добавьте столбец `total` с общим количеством медалей, полученных командами (сумма золотых, серебряных и бронзовых медалей). Укажите медиану по добавленному столбцу.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 4
#
# Выберите строки, соответствующие играм 2022 года. Определите максимальное число золотых медалей, полученных в этом году.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 5
#
# Выберите строки, соответствующие играм, проходившим во Франции и Италии (значения `France` и `Italy` в столбце `host_country`). Определите минимальное значение года в полученном датафрейме, другими словами, определите, когда раньше всего игры принимали эти страны.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 6
#
# Выберите строки, соответствующие командам с *ненулевым* количеством золотых медалей, принимавших участие в играх с 1984 до 2014 года включительно. Построив таблицу частот для столбца `country` в полученном датафрейме, укажите частоту для Финляндии (`Finland`).

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 7
#
# Постройте гистограмму для показателя «количество серебряных медалей». Можно ли считать распределение показателя симметричным? Да/нет

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 8
#
# Отсортируйте строки по убыванию общего количества медалей. Какая страна и в каком году получила больше всего медалей?

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Часть 2
#
# В файле `disney01.csv` сохранены данные по фильмам (мультипликационным фильмам), выпущенных компанией Дисней в разные годы.
#
#
# Показатели в файле:
#
# * `Title`: название фильма;
# * `Company`: компания/компании, выпустившие фильм;
# * `Year`: год выхода фильма;
# * `Time`: продолжительность фильма в минутах;
# * `Language`: язык фильма;
# * `Budget`: бюджет фильма в долларах;
# * `Box office`: кассовый сбор фильма в долларах;
# * `IMDB`: рейтинг фильма от IMDB;
# * `Meta`: рейтинг фильма от Metacritic;
# * `RT`: рейтинг фильма от Rotten Tomatoes.
#
# Загрузите данные из файла `disney01.csv` (скачать [здесь](https://github.com/allatambov/PyReg26/blob/main/disney01.csv)) и сохраните в датафрейм.

# %% [markdown]
# ### Задача 1
#
# Выведите информацию о типах столбцов в датафрейме. Сколько столбцов типа `float`?

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 2
#
# Выведите описательные статистики по всем числовым столбцам датафрейма. Укажите медиану показателя «продолжительность фильма».

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 3
#
# Добавьте столбец `Fail` из 0 и 1, где 1 ставится в случае, если значение рейтинга фильма от IMDB ниже 4.5. Укажите среднее значение, полученное по добавленному столбцу (с точностью до трех знаков после точки).

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 4
#
# Выберите строки, соответствующие фильмам, язык которых *отличается* от английского (`English` в `Language`). Определите минимальное значение рейтинга от Metacritic для выбранных фильмов.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 5
#
# Выберите строки, соответствующие фильмам, выпущенным с 1980 по 1994 год включительно. Построив таблицу частот для столбца `RT` в полученном датафрейме, укажите частоту для значения `84%`.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 6
#
# Выберите строки, соответствующие фильмам, выпущенным компанией только Disney (`Walt Disney Productions` в `Company`) с рейтингом от Rotten Tomatoes 90% или 100%. Определите медианную продолжительность выбранных фильмов.

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 7
#
# Постройте гистограмму для показателя «бюджет фильма». Можно ли считать распределение показателя симметричным? Да/нет

# %%
### YOUR CODE HERE ###

# %% [markdown]
# ### Задача 8
#
# Отсортируйте строки по убыванию рейтинга от Metacritic. У какого фильма рейтинг самый высокий? Укажите его название.

# %%
### YOUR CODE HERE ###
